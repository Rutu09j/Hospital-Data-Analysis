# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Hospital_Data.csv')

# %%
df
# Out:
#         Hospital_Name   Location        Department  Doctors_Count  \
# 0     Wellness Clinic    Chennai       Orthopedics             47
# 1         Fortis Care       Pune               ENT             15
# 2     Wellness Clinic  Ahmedabad        Pediatrics             20
# 3   Heritage Hospital  Hyderabad           Urology              8
# 4       City Hospital    Kolkata        Gynecology             35
# ..                ...        ...               ...            ...
# 95    Wellness Clinic  Bangalore        Gynecology             28
# 96  Heritage Hospital     Jaipur  General Medicine             26
# 97      Healing Touch  Bangalore          Oncology             40
# 98     Metro Hospital    Lucknow         Neurology             42
# 99      Healing Touch  Bangalore           Urology             14
#
#     Patients_Count Admission_Date Discharge_Date  Medical_Expenses
# 0              182     13-12-2023     14-12-2023          31364.88
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Hospital_Name     100 non-null    object
#  1   Location          100 non-null    object
#  2   Department        100 non-null    object
#  3   Doctors_Count     100 non-null    int64
#  4   Patients_Count    100 non-null    int64
#  5   Admission_Date    100 non-null    object
#  6   Discharge_Date    100 non-null    object
#  7   Medical_Expenses  100 non-null    float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 6.4+ KB

# %%
df.isnull().sum()
# Out:
# Hospital_Name       0
# Location            0
# Department          0
# Doctors_Count       0
# Patients_Count      0
# Admission_Date      0
# Discharge_Date      0
# Medical_Expenses    0
# dtype: int64

# %%
df['Admission_Date'] = pd.to_datetime(df['Admission_Date'] , format = '%d-%m-%Y')
df['Discharge_Date'] = pd.to_datetime(df['Discharge_Date'] , format = '%d-%m-%Y')

# %%
print(df)
# Out:
#         Hospital_Name   Location        Department  Doctors_Count  \
# 0     Wellness Clinic    Chennai       Orthopedics             47
# 1         Fortis Care       Pune               ENT             15
# 2     Wellness Clinic  Ahmedabad        Pediatrics             20
# 3   Heritage Hospital  Hyderabad           Urology              8
# 4       City Hospital    Kolkata        Gynecology             35
# ..                ...        ...               ...            ...
# 95    Wellness Clinic  Bangalore        Gynecology             28
# 96  Heritage Hospital     Jaipur  General Medicine             26
# 97      Healing Touch  Bangalore          Oncology             40
# 98     Metro Hospital    Lucknow         Neurology             42
# 99      Healing Touch  Bangalore           Urology             14
#
#     Patients_Count Admission_Date Discharge_Date  Medical_Expenses
# 0              182     2023-12-13     2023-12-14          31364.88
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Hospital_Name     100 non-null    object
#  1   Location          100 non-null    object
#  2   Department        100 non-null    object
#  3   Doctors_Count     100 non-null    int64
#  4   Patients_Count    100 non-null    int64
#  5   Admission_Date    100 non-null    datetime64[ns]
#  6   Discharge_Date    100 non-null    datetime64[ns]
#  7   Medical_Expenses  100 non-null    float64
# dtypes: datetime64[ns](2), float64(1), int64(2), object(3)
# memory usage: 6.4+ KB

# %%
print(df.dtypes)
# Out:
# Hospital_Name               object
# Location                    object
# Department                  object
# Doctors_Count                int64
# Patients_Count               int64
# Admission_Date      datetime64[ns]
# Discharge_Date      datetime64[ns]
# Medical_Expenses           float64
# dtype: object

# %%
df.describe()
# Out:
#        Doctors_Count  Patients_Count       Admission_Date  \
# count     100.000000      100.000000                  100
# mean       26.710000       93.470000  2023-07-12 16:48:00
# min         5.000000       20.000000  2023-01-11 00:00:00
# 25%        15.000000       56.750000  2023-04-04 12:00:00
# 50%        27.500000       84.500000  2023-07-10 12:00:00
# 75%        38.250000      131.500000  2023-10-17 12:00:00
# max        49.000000      198.000000  2023-12-30 00:00:00
# std        13.248438       48.167942                  NaN
#
#             Discharge_Date  Medical_Expenses
# count                  100        100.000000
# mean   2023-07-20 15:36:00      27173.110600
# min    2023-01-25 00:00:00       2854.220000
# 25%    2023-04-17 00:00:00      14688.322500
# 50%    2023-07-24 00:00:00      26320.945000
# 75%    2023-10-26 12:00:00      40741.427500
# max    2024-01-13 00:00:00      49955.410000
# std                    NaN      14001.995544

# %%
# 1 number of patients across all hospitals

# %%
total_patients = df['Patients_Count'].sum()

# %%
print(f"totla patients across all hospitals is: {total_patients}")
# Out:
# totla patients across all hospitals is: 9347

# %%
df.columns
# Out:
# Index(['Hospital_Name', 'Location', 'Department', 'Doctors_Count',
#        'Patients_Count', 'Admission_Date', 'Discharge_Date',
#        'Medical_Expenses'],
#       dtype='object')

# %%
plt.figure(figsize=(16,10))
ax=sns.barplot(x = 'Hospital_Name', y= 'Patients_Count', data = df , color='pink')
plt.title("Number of Patients Across Hospital")
plt.xlabel('Hospital_Name')
plt.ylabel('Patients_Count')
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %% [markdown]
#  # 2. Average Number of Doctors per Hospital
#  #Retrieve the average count of doctors available in each hospital.

# %%
average_dr = df['Doctors_Count'].mean()
print(f"Average Number Of Doctores per Hospital is: {average_dr}")
# Out:
# Average Number Of Doctores per Hospital is: 26.71

# %%
avg_doctors = df['Doctors_Count'].mean() # use mean to calculate avg

# Plot
plt.figure(figsize=(6, 4)) # to  set size
plt.bar(['Average Doctors per Hospital'], [avg_doctors], color='skyblue')
plt.ylabel(' Doctors_Count')
plt.title('Average Number of Doctors per Hospital')
plt.ylim(0, df['Doctors_Count'].max() + 10) # ylim- is vertical axis limit

# Add value label
plt.text(0, avg_doctors + 1, f'{avg_doctors:.2f}', ha='center', fontweight='bold')
# avg_doctors + 1 is y-position just abouve the bar
# f'{avg_doctors:.2f} shows avg with 2 decimal places.
# ha='center' centers the text horizontally
#plt.tight_layout()# adjusts spacing to ensure everything fits nicely in the figure area
plt.show()

# %% [markdown]
# #  Top 3 Departments with the Highest Number of Patients
#  #Find the top 3 hospital departments that have the highest number of patients.

# %%
df.columns
# Out:
# Index(['Hospital_Name', 'Location', 'Department', 'Doctors_Count',
#        'Patients_Count', 'Admission_Date', 'Discharge_Date',
#        'Medical_Expenses'],
#       dtype='object')

# %%
Dept_Patients_Counts = df.groupby("Department")['Patients_Count'].sum()
Top_3_Dept = Dept_Patients_Counts.sort_values(ascending = False).head(3)
print("Top 3 Hospital departments with highest number of patientsd:")
print(Top_3_Dept)
# Out:
# Top 3 Hospital departments with highest number of patientsd:
# Department
# Urology      1766
# Neurology    1229
# ENT          1064
# Name: Patients_Count, dtype: int64

# %%
Top_3_Dept .plot(kind='barh' ,color='mediumseagreen')
plt.title("Top 3 Hospital Dept by Patient Count")
plt.xlabel("Patients Count")
plt.ylabel("Department")
plt.gca().invert_yaxis() # show the highest at the Top# gca is get current axis 
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4) Hospital with the Maximum Medical Expenses
#  #Identify the hospital that recorded the highest medical expenses.

# %%
df.columns
# Out:
# Index(['Hospital_Name', 'Location', 'Department', 'Doctors_Count',
#        'Patients_Count', 'Admission_Date', 'Discharge_Date',
#        'Medical_Expenses'],
#       dtype='object')

# %%
max_exp = df.loc[df['Medical_Expenses'].idxmax()] # idxmax index of max value
print("Hospital with the maximum Medical Expenses:")
print(f"Hospital Name :{max_exp['Hospital_Name']}")
print(f"Medical_Expenses: {max_exp['Medical_Expenses']}")
# Out:
# Hospital with the maximum Medical Expenses:
# Hospital Name :Healing Touch
# Medical_Expenses: 49955.41

# %%
max_exp = df.loc[df['Medical_Expenses'].idxmax()]
plt.figure(figsize =(16,10))
bars=plt.bar(df['Hospital_Name'],df['Medical_Expenses'],color="pink")
bars[df['Medical_Expenses'].idxmax()].set_color('coral')
plt.title("medical Expenses by hospital(max Highlighted)")
plt.xlabel("Hospita Name")
plt.ylabel("Medical Expenses")

plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Daily Average Medical Expenses
# #Calculate the average medical expenses per day for each hospital.

# %%
df.columns

# %%
df['number_of_days'] = (df['Discharge_Date'] - df['Admission_Date']).dt.days+1

# %%
df['expense_per_day'] =df['Medical_Expenses']/df['number_of_days']

# %%
result = df.groupby('Hospital_Name')['expense_per_day'].mean().reset_index()

# %%
result.rename(columns={'expense_per_day': 'average_expense_per_day'} , inplace =True)

# %%
print(result)

# %%
plt.figure(figsize=(16,10))
ax =sns.barplot(x ="Hospital_Name" , y= "average_expense_per_day" , data=result, color="Green")
plt.title("Daily Average Expense per Hospital")
for bars in ax.containers:
    ax.bar_label(bars)
plt.xlabel("Hospital_Name")
plt.ylabel("average_expense_per_day ")
plt.show()

# %% [markdown]
# #  6) Longest Hospital Stay
# #Find the patient with the longest stay by calculating the difference between
#  #Discharge Date and Admission Date.

# %%
df['stay_duration'] = (df['Discharge_Date'] - df['Admission_Date']).dt.days+1
longest_stay_patient = df.loc[df['stay_duration'].idxmax()]
print("Patient with the longest stay:")
print(longest_stay_patient)
# Out:
# Patient with the longest stay:
# Hospital_Name             Apollo Health
# Location                        Lucknow
# Department                          ENT
# Doctors_Count                         9
# Patients_Count                      171
# Admission_Date      2023-04-06 00:00:00
# Discharge_Date      2023-04-21 00:00:00
# Medical_Expenses               21666.78
# stay_duration                        16
# Name: 26, dtype: object

# %%
plt.bar('longest_stay_patient' ,longest_stay_patient['stay_duration'],color = 'skyblue')
plt.title("Patients with longest stay")
plt.ylabel("Number of Days")
plt.show()

# %% [markdown]
#  # 7. Total Patients Treated Per City
#    #Count the total number of patients treated in each city.

# %%
df.columns
# Out:
# Index(['Hospital_Name', 'Location', 'Department', 'Doctors_Count',
#        'Patients_Count', 'Admission_Date', 'Discharge_Date',
#        'Medical_Expenses', 'stay_duration'],
#       dtype='object')

# %%
patients_per_city = df['Location'].value_counts().reset_index()
patients_per_city.columns = ['City','total_patients']
print(patients_per_city)
# Out:
#         City  total_patients
# 0  Ahmedabad              17
# 1     Jaipur              16
# 2  Bangalore              11
# 3    Lucknow              11
# 4  Hyderabad              11
# 5       Pune               9
# 6    Chennai               8
# 7    Kolkata               6
# 8      Delhi               6
# 9     Mumbai               5

# %%
plt.figure(figsize=(16,10))
plt.bar(patients_per_city['City'],patients_per_city['total_patients'], color = 'lightgreen')
plt.title('Total Patients Treated per City')
plt.xlabel("City")
plt.ylabel("Number of Patients")
plt.show()

# %% [markdown]
#  #  8. Average Length of Stay Per Department
#  #Calculate the average number of days patients spend in each department.

# %%
df['stay_duration'] = (df['Discharge_Date'] - df['Admission_Date']).dt.days + 1
avg_stay = df.groupby('Department')['stay_duration'].mean().reset_index()
avg_stay_columns = ['Department' , 'average_stay_days']
print(avg_stay)
# Out:
#          Department  stay_duration
# 0        Cardiology       7.857143
# 1       Dermatology       6.600000
# 2               ENT       9.083333
# 3  General Medicine       8.428571
# 4        Gynecology       8.666667
# 5         Neurology      10.250000
# 6          Oncology       9.111111
# 7       Orthopedics       8.142857
# 8        Pediatrics      10.111111
# 9           Urology       9.722222

# %%
plt.figure(figsize=(16,10))
plt.bar(avg_stay['Department'] ,avg_stay['stay_duration'] ,color='salmon')
plt.title("Average length of stay per Department")
plt.xlabel("Department")
plt.ylabel("Average Stay (Days)")
plt.show()

# %% [markdown]
# # 9. Identify the Department with the Lowest Number of Patients
# #Find the department with the least number of patients.

# %%
df.columns
# Out:
# Index(['Hospital_Name', 'Location', 'Department', 'Doctors_Count',
#        'Patients_Count', 'Admission_Date', 'Discharge_Date',
#        'Medical_Expenses', 'stay_duration'],
#       dtype='object')

# %%
patient_counts = df['Department'].value_counts().reset_index()
patient_counts.columns = ['Department' ,'Patient_count']
lowest_Dept = patient_counts.iloc[-1]
print("Department with the lowest number of patients:")
print(lowest_Dept)
# Out:
# Department with the lowest number of patients:
# Department       Cardiology
# Patient_count             7
# Name: 9, dtype: object

# %%
plt.figure(figsize=(16, 10))
plt.bar(patient_counts['Department'], patient_counts['Patient_count'], color='purple')

# Adding title and labels
plt.title("Department with the Lowest Number of Patients")
plt.xlabel("Department")
plt.ylabel("Number of Patients")

# Display the plot
plt.show()

# %% [markdown]
# #  10. Monthly Medical Expenses Report
#  #Group the data by month and calculate the total medical expenses for each month.

# %%
df['Month_Year'] = df['Admission_Date'].dt.to_period("M")
monthly_expenses = df.groupby('Month_Year')['Medical_Expenses'].sum().reset_index()
print(monthly_expenses)
# Out:
#    Month_Year  Medical_Expenses
# 0     2023-01         173971.54
# 1     2023-02         301722.72
# 2     2023-03         199247.42
# 3     2023-04          88995.93
# 4     2023-05         222986.72
# 5     2023-06         165926.36
# 6     2023-07         211527.13
# 7     2023-08         181039.55
# 8     2023-09         341284.23
# 9     2023-10         158450.68
# 10    2023-11         334370.33
# 11    2023-12         337788.45

# %%
plt.figure(figsize=(16,10))
plt.plot(monthly_expenses['Month_Year'].astype(str) , monthly_expenses['Medical_Expenses'], marker= 'o', color= 'brown')
plt.title("Monthly Medical Expenses Report (based on Admission date)")
plt.xlabel("Month")
plt.ylabel("Total Medical Expenses")
plt.show()
